# %% [markdown]
# <a href="https://colab.research.google.com/github/midnightripper/Word-Count/blob/main/Word_Count_Return.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing English word corpus

# %%
import re
import nltk
nltk.download('words')
from nltk.corpus import words
english_words = set(words.words())
english_words.add('a')
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.

# %%
import re
input_text = '''
00:00:03.240 --> 00:00:06.520
Oh btw, I almost forgot to tell you...

00:00:07.480 --> 00:00:08.760
This show almost got cancelled. Again

00:00:08.760 --> 00:00:09.720
This show almost got cancelled. Again

00:00:10.840 --> 00:00:11.560
Because Airports

00:00:12.520 --> 00:00:15.320
To..I am double vaccinated,

00:00:15.320 --> 00:00:16.760
I have vaccination certificate also

00:00:17.760 --> 00:00:18.560
Bakayda

00:00:18.560 --> 00:00:19.960
To main airport pe chaud se pahucha,

00:00:19.960 --> 00:00:21.760
main kaha ab thodi rok lenge

00:00:22.400 --> 00:00:23.160
Fir vahaan jaake pata chala

00:00:23.160 --> 00:00:24.400
ohh ticket bhi chahiye thi, ohho

00:00:26.760 --> 00:00:29.880
Nahi…thi thi

00:00:29.880 --> 00:00:32.000
Ticket dikhayi usko, aadhar card dikhaya

00:00:32.000 --> 00:00:34.800
to kehti sir RT-PCR

00:00:35.720 --> 00:00:37.560
Maine kaha ma’am – VACCINATION CERTIFICATE

00:00:39.280 --> 00:00:40.280
Keh rahi hai no no sir,

00:00:40.280 --> 00:00:42.080
Keh rahi hai no no sir,
Audience - RT-PCR

00:00:43.480 --> 00:00:48.520
Maine kaha ma’am- scan QR Code

00:00:52.880 --> 00:00:55.480
Keh rahi hai sir, AAR TEE PEE CEE AAR

00:01:04.280 --> 00:01:07.200
Usko laga shayad sunaai nahi de raha hai

00:01:07.200 --> 00:01:09.000
Maine kaha ma’am aap base model maang rahe ho,

00:01:09.000 --> 00:01:10.960
main top model de raha hu

00:01:12.080 --> 00:01:13.480
Keh rahi hai sir,

00:01:13.480 --> 00:01:15.120
RT-PCR

00:01:15.120 --> 00:01:16.600
Uski cassette fass chuki hai

00:01:18.520 --> 00:01:19.680
Maine fir voh wala card khela 

00:01:19.680 --> 00:01:23.760
Maine kaha Ma’am actually I am verified account on Instagram

00:01:26.960 --> 00:01:29.560
Multiple sold out shows pan India Ma’am

00:01:30.840 --> 00:01:33.440
Youtube oh ho

00:01:34.400 --> 00:01:35.720
Keh rahi hai sir,

00:01:35.720 --> 00:01:37.360
RT-PCR

00:01:38.200 --> 00:01:38.720
Vo nahi hil rahi

00:01:38.720 --> 00:01:40.680
Fir maine voh apna Delhi wala card khela

00:01:40.680 --> 00:01:43.760
ki Ma’am, main na aapki baat kara deta hu

00:01:44.440 --> 00:01:47.240
Jiss hospital se jis bande ne khud teeka lagaya hai

00:01:47.240 --> 00:01:48.320
voh khud phone karke baat karlega

00:01:48.320 --> 00:01:49.400
Chief Medical Officer

00:01:49.400 --> 00:01:50.560
Keh rahi hai sir

00:01:50.560 --> 00:01:52.800
Audience - RT-PCR

00:01:52.800 --> 00:01:53.680
Government mandate

Aap please come out of the line, let other passengers... 

00:01:57.200 --> 00:02:00.280
Maine kaha dekh, aisa hai

00:02:00.280 --> 00:02:02.120
Delhi toh main jaa raha hu
'''
# Take both inputs (i.e) Put the english transciption from asr in inputtxt and the hindi transcription form asr in hinditxt

pattern = r'(\d\d):(\d\d):(\d\d)\.(\d\d\d) --> (\d\d):(\d\d):(\d\d)\.(\d\d\d)\n(.+?)\n'
matched= re.findall(pattern, input_text, re.DOTALL)
data= []
for i, match in enumerate(matched, start=1):
    #print(i)
    #print(i, data[i-1])
    start_time = int(match[1]) * 60 + int(match[2]) + float('0.' + match[3])
    end_time = int(match[5]) * 60 + int(match[6]) + float('0.' + match[7])
    word_count = len(match[8].split())
    hindi_count= 0
    for j in match[8].split():
      if j.lower() in english_words:
          hindi_count+=1
    data.append(hindi_count)
    
#print(data)
# This is to detect the valid english words from the transcription generated by checking if the word is present in nltk dataset and then returning the english count
# Mean while the hindi transcription detects almost every word so we will use it to return the total count

def convert_labels(hindi_txt, data):
    pattern = r'(\d\d):(\d\d):(\d\d)\.(\d\d\d) --> (\d\d):(\d\d):(\d\d)\.(\d\d\d)\n(.+?)\n'
    matches = re.findall(pattern, hindi_txt, re.DOTALL)
    #matched= re.findall(pattern, , re.DOTALL)
    output= []
    for i, match in enumerate(matches, start=1):
        #print(i)
        #print(i, data[i-1])
        start_time = int(match[1]) * 60 + int(match[2]) + float('0.' + match[3])
        end_time = int(match[5]) * 60 + int(match[6]) + float('0.' + match[7])
        word_count = len(match[8].split())
        

        output.append(f'{start_time:.6f}\t{end_time:.6f}\t{i},{word_count},{data[i-1]}')

    #print(output)

    return '\n'.join(output)
converted_text= convert_labels(hinditxt, data)
print(converted_text)
# Out:
# 3.240000	6.520000	1,8,6
# 7.480000	8.760000	2,6,5
# 8.760000	9.720000	3,6,5
# 10.840000	11.560000	4,2,1
# 12.520000	15.320000	5,4,2
# 15.320000	16.760000	6,5,5
# 17.760000	18.560000	7,1,0
# 18.560000	19.960000	8,7,4
# 19.960000	21.760000	9,6,2
# 22.400000	23.160000	10,5,2
# 23.160000	24.400000	11,6,1
# 26.760000	29.880000	12,2,0
# 29.880000	32.000000	13,6,2
# 32.000000	34.800000	14,4,2
# 35.720000	37.560000	15,6,3
# 39.280000	40.280000	16,6,2
# 40.280000	42.080000	17,6,2
# 43.480000	48.520000	18,6,3
# 52.880000	55.480000	19,9,3
# 64.280000	67.200000	20,8,1
# 67.200000	69.000000	21,9,3
# 69.000000	70.960000	22,6,4
# 72.080000	73.480000	23,4,0
# 73.480000	75.120000	24,1,0
# 75.120000	76.600000	25,5,1
# 78.520000	79.680000	26,6,2
# 79.680000	83.760000	27,10,6
# 86.960000	89.560000	28,7,4
# 90.840000	93.440000	29,3,2
# 94.400000	95.720000	30,4,0
# 95.720000	97.360000	31,1,0
# 98.200000	98.720000	32,4,0
# 98.720000	100.680000	33,8,2
# 100.680000	103.760000	34,9,2
# ...
